# %%
# Dependencies, imports and pyspark:
! pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      -------------------------------------- 0.0/316.9 MB 435.7 kB/s eta 0:12:08
#      -------------------------------------- 0.1/316.9 MB 544.7 kB/s eta 0:09:42
#      ---------------------------------------- 0.2/316.9 MB 1.7 MB/s eta 0:03:09
#      ---------------------------------------- 0.6/316.9 MB 3.2 MB/s eta 0:01:38
#      ---------------------------------------- 1.1/316.9 MB 4.8 MB/s eta 0:01:07
#      ---------------------------------------- 2.2/316.9 MB 7.8 MB/s eta 0:00:41
#      ---------------------------------------- 2.9/316.9 MB 9.0 MB/s eta 0:00:36
#      ---------------------------------------- 3.6/316.9 MB 9.6 MB/s eta 0:00:33
#       -------------------------------------- 5.1/316.9 MB 12.0 MB/s eta 0:00:26
#       -------------------------------------- 6.1/316.9 MB 13.0 MB/s eta 0:00:24
# ...

# %%
# Create a sparksession:
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("spark").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Create a sparksession:
#       2 from pyspark.sql import SparkSession
# ----> 3 spark = SparkSession.builder.appName("spark").getOrCreate()
#
# File ~\anaconda3\envs\dev\lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pyspark\context.py:515, in SparkContext.getOrCreate(cls, conf)
#     513 with SparkContext._lock:
#     514     if SparkContext._active_spark_context is None:
# ...

# %%
! ls
