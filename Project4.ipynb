# %%
# Initial imports
import pandas as pd
from pathlib import Path
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Loading and Preprocessing
# file_path = Path("C:/Users/sqali/OneDrive/Desktop/bootcampUSE/Projects/Project 4/U.S._Chronic_Disease_Indicators__CDI_.csv")
df_data = pd.read_csv(file_path)
print("Sample Data:")
# Out:
# C:\Users\sqali\AppData\Local\Temp\ipykernel_11296\847086371.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_data = pd.read_csv(file_path)
# Sample Data:

# %%
# df_data.columns

# %%
# Check column names
print("Column Names:")
df_data.columns
# Out:
# Column Names:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
df_data.head()
# Out:
#    YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0       2010     2010           OR          Oregon       NVSS
# 1       2019     2019           AZ         Arizona      YRBSS
# 2       2019     2019           OH            Ohio      YRBSS
# 3       2019     2019           US   United States      YRBSS
# 4       2015     2015           VI  Virgin Islands      YRBSS
#
#                     Topic                      Question  Response  \
# 0  Cardiovascular Disease  Mortality from heart failure       NaN
# 1                 Alcohol       Alcohol use among youth       NaN
# 2                 Alcohol       Alcohol use among youth       NaN
# 3                 Alcohol       Alcohol use among youth       NaN
# 4                 Alcohol       Alcohol use among youth       NaN
#
#   DataValueUnit     DataValueType  ... LocationID  TopicID QuestionID  \
# 0           NaN            Number  ...         41      CVD     CVD1_4
# ...

# %%
# Filter the DataFrame to include only rows where the "Topic" column is "Diabetes"
df_data_diabetes = df_data[df_data['Topic'] == 'Diabetes']

# %%
# Updated rows
print("remaining row",df_data_diabetes.shape)
df_data_diabetes.head()
# Out:
# remaining row (132912, 34)
#       YearStart  YearEnd LocationAbbr LocationDesc DataSource     Topic  \
# 1407       2011     2011           NV       Nevada      BRFSS  Diabetes
# 1429       2016     2016           NV       Nevada      BRFSS  Diabetes
# 1572       2019     2019           NV       Nevada      BRFSS  Diabetes
# 1580       2019     2019           NV       Nevada      BRFSS  Diabetes
# 1598       2017     2017           NE     Nebraska      BRFSS  Diabetes
#
#                                                Question  Response  \
# 1407  Prevalence of diagnosed diabetes among adults ...       NaN
# 1429  Visits to dentist or dental clinic among adult...       NaN
# 1572  Prevalence of diagnosed diabetes among adults ...       NaN
# 1580  Foot examination among adults aged >= 18 years...       NaN
# 1598  Prevalence of high cholesterol among adults ag...       NaN
#
#      DataValueUnit            DataValueType  ... LocationID  TopicID  \
# ...

# %%
df_data_diabetes.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# DataSource                        0
# Topic                             0
# Question                          0
# Response                     132912
# DataValueUnit                 12578
# DataValueType                     0
# DataValue                     59996
# DataValueAlt                  59996
# DataValueFootnoteSymbol       71922
# DatavalueFootnote             71922
# LowConfidenceLimit            68068
# HighConfidenceLimit           68068
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2      132912
# Stratification2              132912
# StratificationCategory3      132912
# Stratification3              132912
# GeoLocation                      92
# ResponseID                   132912
# LocationID                        0
# TopicID                           0
# ...

# %%
# Define a list of columns to drop
columns_to_drop = ['StratificationCategoryID2', 'StratificationID2', 'StratificationCategoryID3','StratificationID3','StratificationCategory3','Stratification3','Response']

# %%
# Display the list of columns to drop
print("Columns to Drop:")
columns_to_drop
# Out:
# Columns to Drop:
# ['StratificationCategoryID2',
#  'StratificationID2',
#  'StratificationCategoryID3',
#  'StratificationID3',
#  'StratificationCategory3',
#  'Stratification3',
#  'Response']

# %%
# Drop the specified columns from the DataFrame
df_data.drop(columns_to_drop, axis=1, inplace=True)

# Filter the DataFrame to include only rows related to diabetes
df_data_diabetes = df_data[df_data['Topic'] == 'Diabetes']

# Print the DataFrame to see the remaining columns related to diabetes
print("DataFrame after dropping columns and filtering for diabetes")
df_data_diabetes.head()
# Out:
# DataFrame after dropping columns and filtering for diabetes
#       YearStart  YearEnd LocationAbbr LocationDesc DataSource     Topic  \
# 1407       2011     2011           NV       Nevada      BRFSS  Diabetes
# 1429       2016     2016           NV       Nevada      BRFSS  Diabetes
# 1572       2019     2019           NV       Nevada      BRFSS  Diabetes
# 1580       2019     2019           NV       Nevada      BRFSS  Diabetes
# 1598       2017     2017           NE     Nebraska      BRFSS  Diabetes
#
#                                                Question DataValueUnit  \
# 1407  Prevalence of diagnosed diabetes among adults ...             %
# 1429  Visits to dentist or dental clinic among adult...             %
# 1572  Prevalence of diagnosed diabetes among adults ...             %
# 1580  Foot examination among adults aged >= 18 years...             %
# 1598  Prevalence of high cholesterol among adults ag...             %
#
# ...

# %%
# Define features set (X) and target variable (y)
# X = df_data.drop(columns_to_drop, axis=1)
# y = df_data["Diabetes"]

# %%
# Splitting into Train and Test sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting StandardScaler
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Creating the decision tree classifier instance or  can user other models
model = tree.DecisionTreeClassifier()
model = model.fit(X_train_scaled, y_train)

# %%
# Fitting the model
model = model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data
predictions = model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("\nConfusion Matrix:")
display(cm_df)
print(f"\nAccuracy Score: {acc_score:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, predictions))
